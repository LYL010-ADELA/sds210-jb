# %% [markdown]
# # W1. Get Started with Notebooks
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HendrikWulf/sds210-jb/blob/main/book/3_python/01_get_started.ipynb)
#
# Welcome!
# In this course, we work almost entirely with Jupyter notebooks. This page shows you how to run them and lets you try things out right away. There’s no “best” option. Choose what fits your setup and learning style.

# %% [markdown]
# ## 1. Setup
# There are multiple ways to run Jupyter notebooks. You can either run them locally on your machine or use an online service like Google Colab or Binder.
#
# ### Using Colab
#
# **Google Colab** (recommended) is a free online service that allows you to run Jupyter notebooks in the cloud without installing anything locally.
#
# For this course, **Colab is the recommended option** if you want to run notebooks online.
#
# To open this notebook in Google Colab, click the **“Open in Colab”** button at the top of the page (or use the Colab link provided on this page). This will open a copy of the notebook directly from the course GitHub repository in Colab, where you can run and modify the code interactively.
#
# ---
#
# ### Using Binder
#
# **Binder** (slower alternative) is another free online service that lets you run Jupyter notebooks in the cloud without local installation.
#
# Binder launches a temporary Jupyter environment based on the course GitHub repository. Startup can take a minute or two, especially when many users access Binder at the same time.
#
# The *launch button* (🚀) in the top right corner starts a temporary Binder session, when you copy `https://mybinder.org` as the URL placeholder. Once launched you can run the notebook in your browser.
#
# > Binder sessions are temporary
# > Any changes you make will be lost when the session ends unless you download your notebook.
#
#
# ---
#
# ### In-page execution
#
# This Jupyter Book supports **in-page execution** (temporary cloud kernel), which allows you to run code cells **directly on this page**, without opening a separate notebook interface.
#
# When you click the *power button* (⏻, top of the page), a **temporary cloud-based Jupyter kernel** is started in the background. Once the session is ready, you can execute the code cells on this page and view the outputs inline.
#
# > This option is useful for **quick experiments, demonstrations, or checking understanding**.
# > It is not intended for longer work sessions or saving progress.
#
# > In-page execution uses a **temporary Binder-backed environment**
# > Startup may take some time, and sessions are not persistent. Any changes or results are lost when the page is refreshed.
#
# ---
#
# ### Running Locally
#
# If you prefer to run notebooks locally on your own machine, you need a **local Python environment** and **JupyterLab**.
# For this course, this means a Conda-based setup. See the Setup sections on [Conda](https://hendrikwulf.github.io/sds210-jb/book/setup/conda/) and [JupyterLab](https://hendrikwulf.github.io/sds210-jb/book/setup/jupyterlab/) for details.
#
# Start JupyterLab from your environment:
#
# ```bash
# jupyter lab
# ```
#
# This opens JupyterLab in your web browser. From there, navigate to the notebook file and run it locally.
#
# For additional convenience, you may also use [VS Code](https://hendrikwulf.github.io/sds210-jb/book/setup/vs-code/) together with [Git](https://hendrikwulf.github.io/sds210-jb/book/setup/git/) to benefit from advanced code editing features and version control. This setup is optional but recommended for longer or more complex projects.
#
# > Running notebooks locally gives you the best performance and full control over your environment, but requires a properly configured local setup. See the [Conda](https://hendrikwulf.github.io/sds210-jb/book/setup/conda/), [JupyterLab](https://hendrikwulf.github.io/sds210-jb/book/setup/jupyterlab/), [VS Code](https://hendrikwulf.github.io/sds210-jb/book/setup/vs-code/), and [Git](https://hendrikwulf.github.io/sds210-jb/book/setup/git/) sections in the Setup chapter.
#
# ---

# %% [markdown]
# ## 2. First Steps
#
# ### About cells
#
# This cell is written in **Markdown**.
# Markdown is used for explanations, notes, and questions. It tells the story of what we’re doing.
#
# **Important:** Markdown cells do **not** run any code. They’re just text.
#
# If you double-click on this cell, you’ll see the *source* and can edit it.
#
# **Try this**
#
# * Find the word *source* above
# * Make it **bold**
# * Run the cell again (Cell Menu: Stop Editing Code, Shortkey: Control + Enter) to see the result
#
# If you’re curious, here’s a short reference for Markdown syntax:
# [https://www.markdownguide.org/basic-syntax/](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# The **next cell** contains Python **code**.
# When you click on it, notice how the cell type changes from *Markdown* to *Code* in the dropdown above.
#
# To run a code cell, click the ▶️ **Run** button.

# %%
# This line prints text to the screen
# Change it so that it prints your own name

print("Aye caramba, I am Hendrik")
# Out:
# Aye caramba, I am Hendrik

# %% [markdown]
# The next code cell works with **numbers**.
#
# **What to do:**
# - Run the cell
# - Change the values of `x` and `y`
# - Run it again and observe what changes
#
# Only the **last line** in a code cell is shown as output automatically.

# %%
x = 3
y = 4

x - y

x + y
# Out:
# 7

# %% [markdown]
# This cell does the **same calculations**, but uses `print()` to explicitly display results.
#
# Note:
# - Calculations happen *inside* `print()`
# - All printed lines are shown
# - This cell **depends on variables from previous cells** (`x` and `y`)
#
# This means the **order** in which you run cells matters.

# %%
print(x - y)

print(x + y)
# Out:
# -1
# 7

# %% [markdown]
# In the final example, we **store results in variables** and then print them.
#
# This is a very common pattern in programming:
# 1. compute something
# 2. store it
# 3. reuse it later

# %%
a = x - y

b = x + y

print("The answers to the two calculations are ", a, " and ", b)
# Out:
# The answers to the two calculations are  -1  and  7

# %% [markdown]
# ### Useful notebook actions
#
# - Add new cells via **Insert** → Cell Above / Below
# - Restart everything with **Kernel → Restart & Run All**
# - Run cells individually or step-by-step
# - Markdown cells render text, code cells produce output
# - You can save notebooks locally (Binder sessions are temporary)

# %% [markdown]
# ## 3. Your tasks
#
# 1. Modify the code so that it prints **your name**
# 2. Change the values of `x` and `y` and observe the results
# 3. Restart the kernel and run **only the last code cell**. What happens? Why?
# 4. Add a new code cell with a very simple calculation
# 5. Add a Markdown cell describing what you did
# 6. Save your code locally, and open it with JupyterLab
